# %%
import ipywidgets as widgets
import torch

# %%
model = torch.load('trained_cnn.pt', map_location=torch.device('cpu'))

# %%
print(model)
# Out:
# OrderedDict([('conv1.weight', tensor([[[[ 3.4697e-01, -5.7412e-01,  3.2555e-01],
#           [ 3.7050e-01, -1.0013e+00,  6.8221e-01],
#           [ 6.6505e-04, -1.3162e-01,  1.2178e-01]]],
#
#
#         [[[-1.2010e-01,  3.0373e-01,  1.3119e-01],
#           [ 2.1793e-01, -1.9619e-01, -7.0962e-02],
#           [-8.2999e-02, -3.0764e-02, -3.4259e-02]]],
#
#
#         [[[ 6.8281e-01,  1.9604e-01, -3.5409e-01],
#           [-4.4736e-01, -3.0726e-01, -3.3136e-01],
#           [-3.0530e-01,  1.8979e-01,  6.1906e-01]]],
#
#
#         [[[ 1.2756e-01, -2.4195e-01,  1.4891e-01],
#           [ 2.9012e-01,  6.1236e-01,  4.0817e-01],
#           [-4.2192e-01, -5.9955e-01, -4.5003e-01]]],
#
#
#         [[[ 2.0165e-01,  8.4839e-03,  4.1717e-02],
#           [-6.8563e-02,  5.1033e-01, -4.1414e-01],
#           [ 1.9146e-01,  1.1448e-01, -3.6330e-01]]],
#
#
#         [[[ 1.4924e-01, -4.3493e-01, -2.4747e-01],
#           [-2.9492e-01, -4.4793e-01, -7.4509e-01],
# ...
